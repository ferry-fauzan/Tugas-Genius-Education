# %%
class Kontak(object):
    def__init__(self,nama,nomor):
        self.nama=nama
        self.nomor=nomor
        
        
kontak=[]

def main():
    print("Selamat datang")
    while True:
        print('--Menu--\n')
        print('1. Daftar Kontak')
        print('2. Tambah Kontak')
        print('3. Edit Kontak')
        print('4. Hapus Kontak')
        print('5. Cari Kontak')
        print('6. Keluar')
        menu=input('Pilih Menu: ')
        if menu=='1':
            dafatr_kontak()
        elif menu=='2':
            tambah_kontak()
        elif menu=='3':
            edit_kontak()
        elif menu=='4':
            hapus_kontak()
        elif menu=='5':
            cari_kontak()
        elif menu--'6':
            print('Program Selesai, sampai jumpa!')
            break
        else:
            print('Menu Tidak Tersedia')

if __name__=='__main__':
    main()


#CREATE
def tambah_kontak():
    print(" ")
    banyakKontak=int(input("Masukkan banyak kontak: "))
    for i in range(banyakKontak):
        print("Masukkan Kontak: ", i+1)
        namaKontak=input("Nama\t:")
        nomorKontak=int(input("Nomor\t:"))
        kontakBaru=kontak[namaKontak, nomorKontak]
        kontak.append(kontakBaru)
        print(" ")
    print("Kontak Berhasil ditambahkan")

    
#READ
def daftar_kontak():
    print(' ')
    if(len(kontak)==0):
        print('Kontak Masih Kosong, silahkan menambahkan kontak')
        print(' ')
    else: 
        i=1
        print('|{i}.\t|{j.nama}\t\t|{j.nomor}\t')
        i+=1
    print(' ')

    
#UPDATE
def edit_kontak():
    print(' ')
    if(len(kontak)==0):
        print('Kotak Masih Kosong, silahkan menambahkan kontak')
        print(' ')
    else: 
        edit=int(input('Masukkan Nomor Urut Kontak: '))
        namaKontak=input('Nama\t: ')
        nomorKontak=int(inut('Nomor\t: '))
        kontakBaru=Kontak(namaKontak, nomorKontak)
        kontak[edit-1]=kontakBaru
        print(' ')
        print(f'Kontak dengan urutan ke-{edit}, Berhasil di edit!\n)
              

              
#DELETE
def hapus_kontak():
    print(' ')
    if(len(kontak)==0):
        print('Kontak Masih Kosong, silahkan menambahkan kontak!')
        print(' ')
    else:
        hapus=int(input(' Masukkan Nomor Urut Kontak: '))
        del kontak[hapus-1]
        print(' ')
        print(f'Kontak dengan urutan ke-{hapus}, Berhasil di hapus!n\')
              

              
#SEARCH
def cari_kontak():
    print('')
    if(len(kontak)==0):
        print('Kotak Masih Kosong, silahkan menambhakn kontak!')
        print(' ')
    else:
        found_kontak=[]
        cari=input('Mencari berdasarkan apa? (nama/nomor)')
        if(cari.lower()=="nama"):
            nama=input('Masukkan nama kontak: ')
            for i in kontak:
                if(i.nama.lower()==nama.lower()):
                    found_kontak.append(i)
                if(len(found_kontak)==0):
                    print("Tidak ditemukan kontak")
                else:
                    print("Berikut hasil kontak berdasarkan nama: ")
                    print(' ')
                    print('|No.\t|Nama|t\t|Nomor Ponsel\t|')
                    i=1
                    for j in found_kontak:
                        print(f'|{i}.\t|{j.nama}\t\t|{j.nomor}\t|')
                        i+=1
                    print('')
                elif(cari.lower()=="nomor"):
                    nomor=input('Masukkan nomor kontak: ')
                    for i in range(0,len(kontak)):
                        found_kontak.append(kontak[i])
                    if(len(found_kontak)==0):
                        print("Tidak ditemukan kontak")
                    else:
                        print("Berikut hasil kontak berdasarkan nomor: ")
                        print('')
                        print('|No.\t|Nama\t\t|Nomor Ponsel\t|')
                        i+=1
                    print('')
                else:
                    print('Tidak dapat mencari diluar kategori tersebut')
